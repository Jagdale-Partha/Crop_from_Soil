# %%
# %pip install soilspecdata numpy pandas matplotlib
# %pip install -U soilspecdata 
# %pip install -e .[dev]
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import the package
from soilspecdata.datasets.ossl import get_ossl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# Obtaining file:///D:/College_Code/CEP_project/Crop_from_Soil
# Note: you may need to restart the kernel to use updated packages.
# ERROR: file:///D:/College_Code/CEP_project/Crop_from_Soil does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# Load soil spectral data
ossl = get_ossl()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Load soil spectral data
# ----> 2 ossl = get_ossl()
#
# File c:\Users\jagda\AppData\Local\Programs\Python\Python313\Lib\site-packages\soilspecdata\datasets\ossl.py:100, in get_ossl(url, force_download)
#      64 # Update dtype dictionary without datetime columns
#      65 dtype = {
#      66     # IDs and codes
#      67     'id.layer_local_c': 'string',
#    (...)     98     'scan.visnir.contact.email_ietf_txt': 'string'
#      99 }
# --> 100 df = pd.read_csv(cache_path, compression='gzip', dtype=dtype,
#     101                  parse_dates=date_columns)
#     102 return OSSLData(df)
#
# ...
